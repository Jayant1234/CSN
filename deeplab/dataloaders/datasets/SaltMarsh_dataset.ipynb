# %%
from torch.utils import data
import os
import numpy as np
import sys
sys.path.append('../')
import custom_transforms as tr
import scipy.misc as m
from PIL import Image
from torchvision import transforms# the problem of version not found was solved by reverting to pillow=6.2.1

# %%
#this class is based on Cityscapes Dataset in the given repo..
class SaltmarshSegmentation(data.Dataset):
    NUM_CLASSES = 9

    def __init__(self, args,root=r"C:\Users\Jayant\Documents\segPipieline\pytorch-deeplab-xception-master\Data", split="train"):

        self.root = root
        self.split = split
        self.args = args
        self.images = []
        self.masks=[]

        self.set_data_names()

        #self.void_classes = [0]
        self.valid_classes = [0,1,2,3,4,5,6,7,8]
        self.class_names = ['Background','Limonium', 'Spartina', 'Batis', 'Other', 'Spart_dead', \
                            'Juncus', 'Sacricornia', 'Borrichia']

        #self.ignore_index = 255
        #self.class_map = dict(zip(self.valid_classes, range(self.NUM_CLASSES)))

    def __len__(self):
        return len(self.images)
    
    def __getitem__(self, index):
        
        img_path = self.root+"/"+self.split+"/"+self.images[index]
        lbl_path = self.root+"/"+self.split+"/"+self.masks[index]

        _img = Image.open(img_path).convert('RGB')
        _tmp = np.array(Image.open(lbl_path), dtype=np.uint8)
        _target = Image.fromarray(_tmp)

        sample = {'image': _img, 'label': _target}

        if self.split == 'train':
            return self.transform_tr(sample)
        elif self.split == 'val':
            return self.transform_val(sample)
        elif self.split == 'test':
            return self.transform_ts(sample)
    def set_data_names(self):  
        for file in os.listdir(self.root+"/"+self.split+"/"):
            if (file.endswith("mask.png")):
                    self.masks.append(file)
                    s=file.split('_')
                    imgname="_".join(s[:-1])+".jpg"
                    self.images.append(imgname)
        return True

    def transform_tr(self, sample):
        composed_transforms = transforms.Compose([
            tr.RandomHorizontalFlip(),
            tr.RandomScaleCrop(base_size=self.args.base_size, crop_size=self.args.crop_size, fill=255),
            tr.RandomGaussianBlur(),
            tr.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)),
            tr.ToTensor()])

        return composed_transforms(sample)

    def transform_val(self, sample):

        composed_transforms = transforms.Compose([
            tr.FixScaleCrop(crop_size=self.args.crop_size),
            tr.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)),
            tr.ToTensor()])

        return composed_transforms(sample)

    def transform_ts(self, sample):

        composed_transforms = transforms.Compose([
            tr.FixedResize(size=self.args.crop_size),
            tr.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)),
            tr.ToTensor()])

        return composed_transforms(sample)

# %%
saltmash=SaltmarshSegmentation([513,513])

# %%
for i in range(0,114): 
    print(saltmash.images[i])
    print(saltmash.masks[i])
    print("-------------------------------------------")
# Out:
# full_2014_Row10_DSC_3516_18.jpg
# full_2014_Row10_DSC_3516_18_mask.png
# -------------------------------------------
# full_2014_Row10_DSC_3516_35.jpg
# full_2014_Row10_DSC_3516_35_mask.png
# -------------------------------------------
# full_2014_Row10_DSC_3516_37.jpg
# full_2014_Row10_DSC_3516_37_mask.png
# -------------------------------------------
# full_2014_Row10_DSC_3516_39.jpg
# full_2014_Row10_DSC_3516_39_mask.png
# -------------------------------------------
# full_2014_Row10_DSC_3516_40.jpg
# full_2014_Row10_DSC_3516_40_mask.png
# -------------------------------------------
# full_2014_Row12_DSC_3692_16.jpg
# full_2014_Row12_DSC_3692_16_mask.png
# -------------------------------------------
# full_2014_Row12_DSC_3692_21.jpg
# full_2014_Row12_DSC_3692_21_mask.png
# -------------------------------------------
# full_2014_Row12_DSC_3692_35.jpg
# full_2014_Row12_DSC_3692_35_mask.png
# -------------------------------------------
# full_2014_Row12_DSC_3692_36.jpg
# full_2014_Row12_DSC_3692_36_mask.png
# -------------------------------------------
# full_2014_Row12_DSC_3692_5.jpg
# full_2014_Row12_DSC_3692_5_mask.png
# -------------------------------------------
# full_2014_Row12_DSC_3692_6.jpg
# full_2014_Row12_DSC_3692_6_mask.png
# -------------------------------------------
# full_2014_Row14_DSC_4009_19.jpg
# full_2014_Row14_DSC_4009_19_mask.png
# -------------------------------------------
# full_2014_Row14_DSC_4009_4.jpg
# full_2014_Row14_DSC_4009_4_mask.png
# -------------------------------------------
# full_2014_Row16_DSC_4288_11.jpg
# full_2014_Row16_DSC_4288_11_mask.png
# -------------------------------------------
# full_2014_Row16_DSC_4288_12.jpg
# full_2014_Row16_DSC_4288_12_mask.png
# -------------------------------------------
# full_2014_Row16_DSC_4288_16.jpg
# full_2014_Row16_DSC_4288_16_mask.png
# -------------------------------------------
# full_2014_Row16_DSC_4288_20.jpg
# full_2014_Row16_DSC_4288_20_mask.png
# -------------------------------------------
# full_2014_Row16_DSC_4288_21.jpg
# full_2014_Row16_DSC_4288_21_mask.png
# -------------------------------------------
# full_2014_Row16_DSC_4288_29.jpg
# full_2014_Row16_DSC_4288_29_mask.png
# -------------------------------------------
# full_2014_Row16_DSC_4288_37.jpg
# full_2014_Row16_DSC_4288_37_mask.png
# -------------------------------------------
# full_2014_Row16_DSC_4288_40.jpg
# full_2014_Row16_DSC_4288_40_mask.png
# -------------------------------------------
# full_2014_Row18_DSC_4649_10.jpg
# full_2014_Row18_DSC_4649_10_mask.png
# -------------------------------------------
# full_2014_Row18_DSC_4649_15.jpg
# full_2014_Row18_DSC_4649_15_mask.png
# -------------------------------------------
# full_2014_Row18_DSC_4649_1.jpg
# full_2014_Row18_DSC_4649_1_mask.png
# -------------------------------------------
# full_2014_Row18_DSC_4649_31.jpg
# full_2014_Row18_DSC_4649_31_mask.png
# -------------------------------------------
# full_2014_Row18_DSC_4649_32.jpg
# full_2014_Row18_DSC_4649_32_mask.png
# -------------------------------------------
# full_2014_Row18_DSC_4649_36.jpg
# full_2014_Row18_DSC_4649_36_mask.png
# -------------------------------------------
# full_2014_Row18_DSC_4649_6.jpg
# full_2014_Row18_DSC_4649_6_mask.png
# -------------------------------------------
# full_2014_Row20_DSC_4868_20.jpg
# full_2014_Row20_DSC_4868_20_mask.png
# -------------------------------------------
# full_2014_Row20_DSC_4868_25.jpg
# full_2014_Row20_DSC_4868_25_mask.png
# -------------------------------------------
# full_2014_Row20_DSC_4868_2.jpg
# full_2014_Row20_DSC_4868_2_mask.png
# -------------------------------------------
# full_2014_Row22_DSC_5345_10.jpg
# full_2014_Row22_DSC_5345_10_mask.png
# -------------------------------------------
# full_2014_Row22_DSC_5345_12.jpg
# full_2014_Row22_DSC_5345_12_mask.png
# -------------------------------------------
# full_2014_Row22_DSC_5345_21.jpg
# full_2014_Row22_DSC_5345_21_mask.png
# -------------------------------------------
# full_2014_Row22_DSC_5345_23.jpg
# full_2014_Row22_DSC_5345_23_mask.png
# -------------------------------------------
# full_2014_Row22_DSC_5345_2.jpg
# full_2014_Row22_DSC_5345_2_mask.png
# -------------------------------------------
# full_2014_Row22_DSC_5345_38.jpg
# full_2014_Row22_DSC_5345_38_mask.png
# -------------------------------------------
# full_2014_Row22_DSC_5345_39.jpg
# full_2014_Row22_DSC_5345_39_mask.png
# -------------------------------------------
# full_2014_Row22_DSC_5345_6.jpg
# full_2014_Row22_DSC_5345_6_mask.png
# -------------------------------------------
# full_2014_Row24_DSC_5715_16.jpg
# full_2014_Row24_DSC_5715_16_mask.png
# -------------------------------------------
# full_2014_Row24_DSC_5715_20.jpg
# full_2014_Row24_DSC_5715_20_mask.png
# -------------------------------------------
# full_2014_Row24_DSC_5715_30.jpg
# full_2014_Row24_DSC_5715_30_mask.png
# -------------------------------------------
# full_2014_Row24_DSC_5715_34.jpg
# full_2014_Row24_DSC_5715_34_mask.png
# -------------------------------------------
# full_2014_Row24_DSC_5715_3.jpg
# full_2014_Row24_DSC_5715_3_mask.png
# -------------------------------------------
# full_2014_Row24_DSC_5715_9.jpg
# full_2014_Row24_DSC_5715_9_mask.png
# -------------------------------------------
# full_2014_Row26_DSC_6104_22.jpg
# full_2014_Row26_DSC_6104_22_mask.png
# -------------------------------------------
# full_2014_Row26_DSC_6104_23.jpg
# full_2014_Row26_DSC_6104_23_mask.png
# -------------------------------------------
# full_2014_Row26_DSC_6104_28.jpg
# full_2014_Row26_DSC_6104_28_mask.png
# -------------------------------------------
# full_2014_Row26_DSC_6104_36.jpg
# full_2014_Row26_DSC_6104_36_mask.png
# -------------------------------------------
# full_2014_Row26_DSC_6104_39.jpg
# full_2014_Row26_DSC_6104_39_mask.png
# -------------------------------------------
# full_2014_Row26_DSC_6104_3.jpg
# full_2014_Row26_DSC_6104_3_mask.png
# -------------------------------------------
# full_2014_Row26_DSC_6104_8.jpg
# full_2014_Row26_DSC_6104_8_mask.png
# -------------------------------------------
# full_2014_Row28_DSC_6413_11.jpg
# full_2014_Row28_DSC_6413_11_mask.png
# -------------------------------------------
# full_2014_Row28_DSC_6413_36.jpg
# full_2014_Row28_DSC_6413_36_mask.png
# -------------------------------------------
# full_2014_Row30_DSC_6738_15.jpg
# full_2014_Row30_DSC_6738_15_mask.png
# -------------------------------------------
# full_2014_Row30_DSC_6738_19.jpg
# full_2014_Row30_DSC_6738_19_mask.png
# -------------------------------------------
# full_2014_Row30_DSC_6738_28.jpg
# full_2014_Row30_DSC_6738_28_mask.png
# -------------------------------------------
# full_2014_Row30_DSC_6738_35.jpg
# full_2014_Row30_DSC_6738_35_mask.png
# -------------------------------------------
# full_2014_Row30_DSC_6738_3.jpg
# full_2014_Row30_DSC_6738_3_mask.png
# -------------------------------------------
# full_2014_Row30_DSC_6738_41.jpg
# full_2014_Row30_DSC_6738_41_mask.png
# -------------------------------------------
# full_2014_Row32_DSC_6738_12.jpg
# full_2014_Row32_DSC_6738_12_mask.png
# -------------------------------------------
# full_2014_Row32_DSC_6738_17.jpg
# full_2014_Row32_DSC_6738_17_mask.png
# -------------------------------------------
# full_2014_Row32_DSC_6738_20.jpg
# full_2014_Row32_DSC_6738_20_mask.png
# -------------------------------------------
# full_2014_Row32_DSC_6738_25.jpg
# full_2014_Row32_DSC_6738_25_mask.png
# -------------------------------------------
# full_2014_Row32_DSC_6738_30.jpg
# full_2014_Row32_DSC_6738_30_mask.png
# -------------------------------------------
# full_2014_Row32_DSC_6738_31.jpg
# full_2014_Row32_DSC_6738_31_mask.png
# -------------------------------------------
# full_2014_Row32_DSC_6738_3.jpg
# full_2014_Row32_DSC_6738_3_mask.png
# -------------------------------------------
# full_2014_Row34_DSC_7387_13.jpg
# full_2014_Row34_DSC_7387_13_mask.png
# -------------------------------------------
# full_2014_Row34_DSC_7387_16.jpg
# full_2014_Row34_DSC_7387_16_mask.png
# -------------------------------------------
# full_2014_Row34_DSC_7387_19.jpg
# full_2014_Row34_DSC_7387_19_mask.png
# -------------------------------------------
# full_2014_Row34_DSC_7387_1.jpg
# full_2014_Row34_DSC_7387_1_mask.png
# -------------------------------------------
# full_2014_Row34_DSC_7387_26.jpg
# full_2014_Row34_DSC_7387_26_mask.png
# -------------------------------------------
# full_2014_Row34_DSC_7387_39.jpg
# full_2014_Row34_DSC_7387_39_mask.png
# -------------------------------------------
# full_2014_Row36_DSC_7785_19.jpg
# full_2014_Row36_DSC_7785_19_mask.png
# -------------------------------------------
# full_2014_Row36_DSC_7785_24.jpg
# full_2014_Row36_DSC_7785_24_mask.png
# -------------------------------------------
# full_2014_Row36_DSC_7785_27.jpg
# full_2014_Row36_DSC_7785_27_mask.png
# -------------------------------------------
# full_2014_Row36_DSC_7785_33.jpg
# full_2014_Row36_DSC_7785_33_mask.png
# -------------------------------------------
# full_2014_Row36_DSC_7785_34.jpg
# full_2014_Row36_DSC_7785_34_mask.png
# -------------------------------------------
# full_2014_Row36_DSC_7785_35.jpg
# full_2014_Row36_DSC_7785_35_mask.png
# -------------------------------------------
# full_2014_Row36_DSC_7785_6.jpg
# full_2014_Row36_DSC_7785_6_mask.png
# -------------------------------------------
# full_2014_Row38_DSC_8028_11.jpg
# full_2014_Row38_DSC_8028_11_mask.png
# -------------------------------------------
# full_2014_Row38_DSC_8028_15.jpg
# full_2014_Row38_DSC_8028_15_mask.png
# -------------------------------------------
# full_2014_Row38_DSC_8028_1.jpg
# full_2014_Row38_DSC_8028_1_mask.png
# -------------------------------------------
# full_2014_Row38_DSC_8028_31.jpg
# full_2014_Row38_DSC_8028_31_mask.png
# -------------------------------------------
# full_2014_Row38_DSC_8028_32.jpg
# full_2014_Row38_DSC_8028_32_mask.png
# -------------------------------------------
# full_2014_Row38_DSC_8028_7.jpg
# full_2014_Row38_DSC_8028_7_mask.png
# -------------------------------------------
# full_2014_Row40_DSC_8320_13.jpg
# full_2014_Row40_DSC_8320_13_mask.png
# -------------------------------------------
# full_2014_Row40_DSC_8320_18.jpg
# full_2014_Row40_DSC_8320_18_mask.png
# -------------------------------------------
# full_2014_Row40_DSC_8320_35.jpg
# full_2014_Row40_DSC_8320_35_mask.png
# -------------------------------------------
# full_2014_Row40_DSC_8320_40.jpg
# full_2014_Row40_DSC_8320_40_mask.png
# -------------------------------------------
# full_2014_Row44_DSC_9129_16.jpg
# full_2014_Row44_DSC_9129_16_mask.png
# -------------------------------------------
# full_2014_Row44_DSC_9129_21.jpg
# full_2014_Row44_DSC_9129_21_mask.png
# -------------------------------------------
# full_2014_Row44_DSC_9129_28.jpg
# full_2014_Row44_DSC_9129_28_mask.png
# -------------------------------------------
# full_2014_Row44_DSC_9129_31.jpg
# full_2014_Row44_DSC_9129_31_mask.png
# -------------------------------------------
# full_2014_Row44_DSC_9129_32.jpg
# full_2014_Row44_DSC_9129_32_mask.png
# -------------------------------------------
# full_2014_Row48_DSC_9810_11.jpg
# full_2014_Row48_DSC_9810_11_mask.png
# -------------------------------------------
# full_2014_Row48_DSC_9810_14.jpg
# full_2014_Row48_DSC_9810_14_mask.png
# -------------------------------------------
# full_2014_Row48_DSC_9810_22.jpg
# full_2014_Row48_DSC_9810_22_mask.png
# -------------------------------------------
# full_2014_Row48_DSC_9810_27.jpg
# full_2014_Row48_DSC_9810_27_mask.png
# -------------------------------------------
# full_2014_Row48_DSC_9810_28.jpg
# full_2014_Row48_DSC_9810_28_mask.png
# -------------------------------------------
# full_2014_Row48_DSC_9810_2.jpg
# full_2014_Row48_DSC_9810_2_mask.png
# -------------------------------------------
# full_2014_Row48_DSC_9810_35.jpg
# full_2014_Row48_DSC_9810_35_mask.png
# -------------------------------------------
# full_2014_Row48_DSC_9810_3.jpg
# full_2014_Row48_DSC_9810_3_mask.png
# -------------------------------------------
# full_2014_Row54_DSC_0587_17.jpg
# full_2014_Row54_DSC_0587_17_mask.png
# -------------------------------------------
# full_2014_Row54_DSC_0587_25.jpg
# full_2014_Row54_DSC_0587_25_mask.png
# -------------------------------------------
# full_2014_Row54_DSC_0587_31.jpg
# full_2014_Row54_DSC_0587_31_mask.png
# -------------------------------------------
# full_2014_Row54_DSC_0587_32.jpg
# full_2014_Row54_DSC_0587_32_mask.png
# -------------------------------------------
# full_2014_Row54_DSC_0587_36.jpg
# full_2014_Row54_DSC_0587_36_mask.png
# -------------------------------------------
# full_2014_Row58_DSC_1639_10.jpg
# full_2014_Row58_DSC_1639_10_mask.png
# -------------------------------------------
# full_2014_Row58_DSC_1639_12.jpg
# full_2014_Row58_DSC_1639_12_mask.png
# -------------------------------------------
# full_2014_Row58_DSC_1639_13.jpg
# full_2014_Row58_DSC_1639_13_mask.png
# -------------------------------------------
# full_2014_Row58_DSC_1639_17.jpg
# full_2014_Row58_DSC_1639_17_mask.png
# -------------------------------------------
# full_2014_Row58_DSC_1639_8.jpg
# full_2014_Row58_DSC_1639_8_mask.png
# -------------------------------------------
# full_2014_Row6_DSC_3203_13.jpg
# full_2014_Row6_DSC_3203_13_mask.png
# -------------------------------------------

# %%
s=saltmash.masks[0].split('_')
imgname="_".join(s[:-1])+".jpg"
imgname
# Out:
# 'full_2014_Row10_DSC_3516_18.jpg'

# %%
def test_get_data_names(rootdir,data_type,masks=[],images=[]):  
        for file in os.listdir(rootdir+"train"+"/"):
            if(data_type=="masks"):
                if (file.endswith("mask.png")):
                    masks.append(file)
            else : 
                if not (file.endswith("mask.png")):
                    images.append(file)
        return masks if data_type=="masks" else images

# %%
#from dataloaders.utils import decode_segmap
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import argparse

parser = argparse.ArgumentParser()
args = parser.parse_args()
args.base_size = 513
args.crop_size = 513

cityscapes_train = SaltmarshSegmentation(args, split='train')
dataloader = DataLoader(cityscapes_train, batch_size=2, shuffle=True, num_workers=2)
for ii, sample in enumerate(dataloader):
    for jj in range(sample["image"].size()[0]):
        img = sample['image'].numpy()
        gt = sample['label'].numpy()
        segmap= np.array(gt[jj]).astype(np.uint8)
        img_tmp = np.transpose(img[jj], axes=[1, 2, 0])
        img_tmp *= (0.229, 0.224, 0.225)
        img_tmp += (0.485, 0.456, 0.406)
        img_tmp *= 255.0
        img_tmp = img_tmp.astype(np.uint8)
        plt.figure()
        plt.title('display')
        plt.subplot(211)
        plt.imshow(img_tmp)
        plt.subplot(212)
        plt.imshow(segmap)
        
        if ii == 1:
            break
# Out:
# usage: ipykernel_launcher.py [-h]
# ipykernel_launcher.py: error: unrecognized arguments: -f C:\Users\Jayant\AppData\Roaming\jupyter\runtime\kernel-fc545779-e3c9-4e0e-b134-4c465f5b965a.json
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# C:\Users\Jayant\Anaconda3\envs\pyseg\lib\site-packages\IPython\core\interactiveshell.py:3327: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
